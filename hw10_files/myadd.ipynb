# %%
from pynq import Overlay
overlay = Overlay('/home/xilinx/add.bit')

# %%
help(overlay)

# %%
overlay.ip_dict

# check add_0 is in the ip_dict

# %%
add_ip = overlay.add_0
help(add_ip)

# %%
add_ip.write(0x10, 4)
add_ip.write(0x18, 5)
add_ip.read(0x20)

# %%
## driver set up 

from pynq import DefaultIP

class AddDriver(DefaultIP):
    def __init__(self, description):
        super().__init__(description=description)

    bindto = ['xilinx.com:hls:add:1.0']

    def add(self, a, b):
        self.write(0x10, a)
        self.write(0x18, b)
        return self.read(0x20)

# %%
    
overlay = Overlay('/home/xilinx/add.bit')
help(overlay)

# %%
overlay.add_0.add(15,20)

# %%
add_ip = overlay.add_0
help(add_ip)
